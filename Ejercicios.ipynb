# %% [markdown]
# # Ejercicio 1: Cargar un modelo preentrenado
#
# En este notebook, aprenderás a cargar un modelo preentrenado en PyTorch y explorar su arquitectura.
#
# **Objetivo:** Familiarizarte con el uso de modelos preentrenados en `torchvision.models`.
#
# ---

# %% [markdown]
# ### Pregunta de autocompletar
#
# Completa el siguiente código para cargar el modelo preentrenado `ResNet50` de la biblioteca `torchvision.models`.

# %%
# Importar las librerías necesarias
import torch
from torchvision import models
from torchvision.models import ResNet50_Weights

# Completa el modelo aquí
model = models.______(weights=ResNet50_Weights.IMAGENET1K_V1)

# %% [markdown]
# ### Evaluación
#
# El siguiente código evaluará tu respuesta. Si es correcta, obtendrás un mensaje de éxito.

# %%
# Evaluación de la respuesta
def evaluar_respuesta(codigo):
    if 'resnet50' in codigo.lower():
        print("✅ ¡Correcto! Has cargado el modelo ResNet50 correctamente.")
    else:
        print("❌ Respuesta incorrecta. Intenta usar 'resnet50' como modelo preentrenado.")

# %%
# Sustituye 'TU_RESPUESTA' por el código que hayas escrito
codigo_estudiante = "resnet50"
evaluar_respuesta(codigo_estudiante)
# Out:
# ✅ ¡Correcto! Has cargado el modelo ResNet50 correctamente.

# %% [markdown]
# # Ejercicio 2: Transformaciones en Data Augmentation
#
# En este notebook, aprenderás a definir una transformación par Data Augmentation.
#
# **Objetivo:** Familiarizarte con el uso de transformaciones en `torchvision.transforms`.
#
# ---

# %% [markdown]
# ### Pregunta de autocompletar
#
# Completa el siguiente código para definir una transformación de resize de 224 tanto para el "train" como "val".

# %%
# Importar las librerías necesarias
import torch
from torchvision import models, transforms

# Completa la transformación acá
data_transforms = {
    'train': transforms.Compose([
        transforms._____(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms._____(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %% [markdown]
# ### Evaluación
#
# El siguiente código evaluará tu respuesta. Si es correcta, obtendrás un mensaje de éxito.

# %%
# Evaluación de la respuesta
def evaluar_respuesta(codigo):
    if 'Resize' in codigo.lower():
        print("✅ ¡Correcto! Has definido el resize correctamente.")
    else:
        print("❌ Respuesta incorrecta. Intenta usar 'Resize' como transformación.")

# Sustituye 'TU_RESPUESTA' por el código que hayas escrito
codigo_estudiante = "TU_RESPUESTA"
evaluar_respuesta(codigo_estudiante)

# %% [markdown]
# # Ejercicio 3: Ajustar el Learning Rate
#
# Ajusta el learning rate para agilizar el entrenamiento.
#
# **Objetivo:** Familiarizarte con el uso learning rate.
#
# ---

# %% [markdown]
# ### Pregunta de autocompletar
#
# Modifica el learning rate a 0.1 para agilizar el entrenamiento.

# %%
# Importar las librerías necesarias
import torch
from torchvision import models
import torch.optim as optim

# Definir el modelo
model_ft = models.resnet50(weights=None)

# Observe que todos los parámetros están siendo optimizados
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# %% [markdown]
# ### Evaluación
#
# El siguiente código evaluará tu respuesta. Si es correcta, obtendrás un mensaje de éxito.

# %%
# Evaluación de la respuesta
def evaluar_respuesta(codigo):
    # Elimina todos los espacios en blanco del código para hacer la comparación
    codigo = codigo.replace(" ", "")

    if 'lr=0.1' in codigo.lower():
        print("✅ ¡Correcto! Has definido el learning rate correctamente.")
    else:
        print("❌ Respuesta incorrecta. Intenta usar 'lr=0.1'.")

# %%
# Sustituye 'TU_RESPUESTA' por el código que hayas escrito
codigo_estudiante = "lr = 0.1"
evaluar_respuesta(codigo_estudiante)
# Out:
# ✅ ¡Correcto! Has definido el learning rate correctamente.
